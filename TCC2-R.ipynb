# %%
#install.packages("frbs")
# Out:
# package 'frbs' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\angel\AppData\Local\Temp\RtmpsHKrZT\downloaded_packages

# %% [markdown]
# https://rdrr.io/cran/frbs/src/demo/FRBCS.W.Iris.R

# %%
library(frbs)

## Input data
data(iris)
# Out:
# Warning message:
# "package 'frbs' was built under R version 3.6.3"

# %%
set.seed(2)
irisShuffled <- iris[sample(nrow(iris)),]
irisShuffled[,5] <- unclass(irisShuffled[,5])
tra.iris <- irisShuffled[1:105,]
tst.iris <- irisShuffled[106:nrow(irisShuffled),1:4]
real.iris <- matrix(irisShuffled[106:nrow(irisShuffled),5], ncol = 1)
range.data.input <- matrix(c(4.3, 7.9, 2.0, 4.4, 1.0, 6.9, 0.1, 2.5), nrow=2)
 
## Set the method and its parameters
method.type <- "FRBCS.W"
control <- list(num.labels = 7, type.mf = "GAUSSIAN", type.tnorm = "MIN", 
                type.snorm = "MAX", type.implication.func = "ZADEH")  

## Generate fuzzy model
object <- frbs.learn(tra.iris, range.data.input, method.type, control)

object$rule
# Out:
#       [,1] [,2]         [,3] [,4]     [,5] [,6]        [,7] [,8]     [,9]
#  [1,] IF   Sepal.Length is   medium   and  Sepal.Width is   small    and
#  [2,] IF   Sepal.Length is   v.large  and  Sepal.Width is   large    and
#  [3,] IF   Sepal.Length is   large    and  Sepal.Width is   medium   and
#  [4,] IF   Sepal.Length is   large    and  Sepal.Width is   small    and
#  [5,] IF   Sepal.Length is   small    and  Sepal.Width is   small    and
#  [6,] IF   Sepal.Length is   medium   and  Sepal.Width is   small    and
#  [7,] IF   Sepal.Length is   medium   and  Sepal.Width is   small    and
#  [8,] IF   Sepal.Length is   v.small  and  Sepal.Width is   medium   and
#  [9,] IF   Sepal.Length is   v.large  and  Sepal.Width is   medium   and
# [10,] IF   Sepal.Length is   large    and  Sepal.Width is   v.small  and
# [11,] IF   Sepal.Length is   small    and  Sepal.Width is   v.small  and
# [12,] IF   Sepal.Length is   small    and  Sepal.Width is   v.small  and
# [13,] IF   Sepal.Length is   small    and  Sepal.Width is   small    and
# [14,] IF   Sepal.Length is   small    and  Sepal.Width is   v.large  and
# [15,] IF   Sepal.Length is   small    and  Sepal.Width is   v.large  and
# [16,] IF   Sepal.Length is   small    and  Sepal.Width is   large    and
# [17,] IF   Sepal.Length is   vv.small and  Sepal.Width is   medium   and
# [18,] IF   Sepal.Length is   large    and  Sepal.Width is   medium   and
# [19,] IF   Sepal.Length is   medium   and  Sepal.Width is   medium   and
# [20,] IF   Sepal.Length is   medium   and  Sepal.Width is   small    and
# [21,] IF   Sepal.Length is   medium   and  Sepal.Width is   medium   and
# [22,] IF   Sepal.Length is   v.small  and  Sepal.Width is   medium   and
# [23,] IF   Sepal.Length is   medium   and  Sepal.Width is   small    and
# [24,] IF   Sepal.Length is   vv.large and  Sepal.Width is   small    and
# [25,] IF   Sepal.Length is   small    and  Sepal.Width is   v.small  and
# [26,] IF   Sepal.Length is   v.small  and  Sepal.Width is   v.small  and
# [27,] IF   Sepal.Length is   v.small  and  Sepal.Width is   large    and
# [28,] IF   Sepal.Length is   v.small  and  Sepal.Width is   large    and
# [29,] IF   Sepal.Length is   vv.small and  Sepal.Width is   small    and
# [30,] IF   Sepal.Length is   small    and  Sepal.Width is   small    and
# [31,] ...  ...          ...  ...      ...  ...         ...  ...      ...
# [32,] IF   Sepal.Length is   large    and  Sepal.Width is   small    and
# [33,] IF   Sepal.Length is   v.large  and  Sepal.Width is   small    and
# [34,] IF   Sepal.Length is   small    and  Sepal.Width is   small    and
# [35,] IF   Sepal.Length is   large    and  Sepal.Width is   small    and
# [36,] IF   Sepal.Length is   medium   and  Sepal.Width is   v.small  and
# [37,] IF   Sepal.Length is   large    and  Sepal.Width is   small    and
# [38,] IF   Sepal.Length is   small    and  Sepal.Width is   v.large  and
# [39,] IF   Sepal.Length is   large    and  Sepal.Width is   small    and
# [40,] IF   Sepal.Length is   v.large  and  Sepal.Width is   small    and
# [41,] IF   Sepal.Length is   small    and  Sepal.Width is   small    and
# [42,] IF   Sepal.Length is   medium   and  Sepal.Width is   medium   and
# [43,] IF   Sepal.Length is   v.small  and  Sepal.Width is   small    and
# [44,] IF   Sepal.Length is   large    and  Sepal.Width is   medium   and
# [45,] IF   Sepal.Length is   v.small  and  Sepal.Width is   medium   and
# [46,] IF   Sepal.Length is   small    and  Sepal.Width is   medium   and
# [47,] IF   Sepal.Length is   large    and  Sepal.Width is   medium   and
# [48,] IF   Sepal.Length is   v.small  and  Sepal.Width is   large    and
# [49,] IF   Sepal.Length is   small    and  Sepal.Width is   large    and
# [50,] IF   Sepal.Length is   medium   and  Sepal.Width is   small    and
# [51,] IF   Sepal.Length is   large    and  Sepal.Width is   medium   and
# [52,] IF   Sepal.Length is   small    and  Sepal.Width is   v.large  and
# [53,] IF   Sepal.Length is   v.small  and  Sepal.Width is   vv.small and
# [54,] IF   Sepal.Length is   vv.large and  Sepal.Width is   large    and
# [55,] IF   Sepal.Length is   large    and  Sepal.Width is   medium   and
# [56,] IF   Sepal.Length is   medium   and  Sepal.Width is   v.small  and
# [57,] IF   Sepal.Length is   medium   and  Sepal.Width is   small    and
# [58,] IF   Sepal.Length is   vv.small and  Sepal.Width is   large    and
# [59,] IF   Sepal.Length is   vv.small and  Sepal.Width is   medium   and
# [60,] IF   Sepal.Length is   small    and  Sepal.Width is   medium   and
# [61,] IF   Sepal.Length is   large    and  Sepal.Width is   medium   and
#       [,10]        [,11] [,12]    [,13] [,14]       [,15] [,16]    [,17]
#  [1,] Petal.Length is    medium   and   Petal.Width is    medium   THEN
#  [2,] Petal.Length is    v.large  and   Petal.Width is    vv.large THEN
#  [3,] Petal.Length is    v.large  and   Petal.Width is    v.large  THEN
#  [4,] Petal.Length is    large    and   Petal.Width is    medium   THEN
#  [5,] Petal.Length is    large    and   Petal.Width is    v.large  THEN
#  [6,] Petal.Length is    large    and   Petal.Width is    medium   THEN
#  [7,] Petal.Length is    large    and   Petal.Width is    large    THEN
#  [8,] Petal.Length is    vv.small and   Petal.Width is    vv.small THEN
#  [9,] Petal.Length is    v.large  and   Petal.Width is    large    THEN
# [10,] Petal.Length is    v.large  and   Petal.Width is    large    THEN
# [11,] Petal.Length is    medium   and   Petal.Width is    medium   THEN
# [12,] Petal.Length is    medium   and   Petal.Width is    small    THEN
# [13,] Petal.Length is    medium   and   Petal.Width is    medium   THEN
# [14,] Petal.Length is    v.small  and   Petal.Width is    v.small  THEN
# [15,] Petal.Length is    vv.small and   Petal.Width is    v.small  THEN
# [16,] Petal.Length is    vv.small and   Petal.Width is    vv.small THEN
# [17,] Petal.Length is    vv.small and   Petal.Width is    vv.small THEN
# [18,] Petal.Length is    v.large  and   Petal.Width is    vv.large THEN
# [19,] Petal.Length is    large    and   Petal.Width is    large    THEN
# [20,] Petal.Length is    large    and   Petal.Width is    large    THEN
# [21,] Petal.Length is    v.large  and   Petal.Width is    vv.large THEN
# [22,] Petal.Length is    v.small  and   Petal.Width is    v.small  THEN
# [23,] Petal.Length is    v.large  and   Petal.Width is    large    THEN
# [24,] Petal.Length is    vv.large and   Petal.Width is    v.large  THEN
# [25,] Petal.Length is    large    and   Petal.Width is    v.large  THEN
# [26,] Petal.Length is    small    and   Petal.Width is    small    THEN
# [27,] Petal.Length is    v.small  and   Petal.Width is    v.small  THEN
# [28,] Petal.Length is    vv.small and   Petal.Width is    vv.small THEN
# [29,] Petal.Length is    vv.small and   Petal.Width is    vv.small THEN
# [30,] Petal.Length is    large    and   Petal.Width is    large    THEN
# [31,] ...          ...   ...      ...   ...         ...   ...      ...
# [32,] Petal.Length is    medium   and   Petal.Width is    medium   THEN
# [33,] Petal.Length is    v.large  and   Petal.Width is    v.large  THEN
# [34,] Petal.Length is    large    and   Petal.Width is    vv.large THEN
# [35,] Petal.Length is    large    and   Petal.Width is    large    THEN
# [36,] Petal.Length is    medium   and   Petal.Width is    small    THEN
# [37,] Petal.Length is    large    and   Petal.Width is    v.large  THEN
# [38,] Petal.Length is    v.small  and   Petal.Width is    vv.small THEN
# [39,] Petal.Length is    v.large  and   Petal.Width is    v.large  THEN
# [40,] Petal.Length is    v.large  and   Petal.Width is    large    THEN
# [41,] Petal.Length is    medium   and   Petal.Width is    small    THEN
# [42,] Petal.Length is    large    and   Petal.Width is    v.large  THEN
# [43,] Petal.Length is    vv.small and   Petal.Width is    vv.small THEN
# [44,] Petal.Length is    large    and   Petal.Width is    large    THEN
# [45,] Petal.Length is    v.small  and   Petal.Width is    vv.small THEN
# [46,] Petal.Length is    v.small  and   Petal.Width is    vv.small THEN
# [47,] Petal.Length is    v.large  and   Petal.Width is    large    THEN
# [48,] Petal.Length is    v.small  and   Petal.Width is    vv.small THEN
# [49,] Petal.Length is    v.small  and   Petal.Width is    vv.small THEN
# [50,] Petal.Length is    v.large  and   Petal.Width is    medium   THEN
# [51,] Petal.Length is    large    and   Petal.Width is    medium   THEN
# [52,] Petal.Length is    vv.small and   Petal.Width is    vv.small THEN
# [53,] Petal.Length is    medium   and   Petal.Width is    small    THEN
# [54,] Petal.Length is    v.large  and   Petal.Width is    v.large  THEN
# [55,] Petal.Length is    large    and   Petal.Width is    v.large  THEN
# [56,] Petal.Length is    large    and   Petal.Width is    v.large  THEN
# [57,] Petal.Length is    medium   and   Petal.Width is    large    THEN
# [58,] Petal.Length is    vv.small and   Petal.Width is    vv.small THEN
# [59,] Petal.Length is    v.small  and   Petal.Width is    vv.small THEN
# [60,] Petal.Length is    vv.small and   Petal.Width is    vv.small THEN
# [61,] Petal.Length is    medium   and   Petal.Width is    medium   THEN
#       [,18]   [,19] [,20]
#  [1,] Species is    2
#  [2,] Species is    3
#  [3,] Species is    3
#  [4,] Species is    2
#  [5,] Species is    3
#  [6,] Species is    2
#  [7,] Species is    2
#  [8,] Species is    1
#  [9,] Species is    3
# [10,] Species is    3
# [11,] Species is    2
# [12,] Species is    2
# [13,] Species is    2
# [14,] Species is    1
# [15,] Species is    1
# [16,] Species is    1
# [17,] Species is    1
# [18,] Species is    3
# [19,] Species is    2
# [20,] Species is    3
# [21,] Species is    3
# [22,] Species is    1
# [23,] Species is    3
# [24,] Species is    3
# [25,] Species is    3
# [26,] Species is    2
# [27,] Species is    1
# [28,] Species is    1
# [29,] Species is    1
# [30,] Species is    2
# [31,] ...     ...   ...
# [32,] Species is    2
# [33,] Species is    3
# [34,] Species is    3
# [35,] Species is    2
# [36,] Species is    2
# [37,] Species is    3
# [38,] Species is    1
# [39,] Species is    3
# [40,] Species is    3
# [41,] Species is    2
# [42,] Species is    3
# [43,] Species is    1
# [44,] Species is    2
# [45,] Species is    1
# [46,] Species is    1
# [47,] Species is    3
# [48,] Species is    1
# [49,] Species is    1
# [50,] Species is    3
# [51,] Species is    2
# [52,] Species is    1
# [53,] Species is    2
# [54,] Species is    3
# [55,] Species is    3
# [56,] Species is    3
# [57,] Species is    2
# [58,] Species is    1
# [59,] Species is    1
# [60,] Species is    1
# [61,] Species is    2

# %%
## Predicting step
res.test <- predict(object, tst.iris)

## error calculation
err = 100*sum(real.iris!=res.test)/nrow(real.iris)

print("The result: ")
print(res.test)
print("FRBCS.W: percentage Error on Iris")
print(err)
# Out:
# [1] "The result: "
#       [,1]
#  [1,]    2
#  [2,]    3
#  [3,]    1
#  [4,]    3
#  [5,]    1
#  [6,]    1
#  [7,]    3
#  [8,]    1
#  [9,]    2
# [10,]    2
# [11,]    2
# [12,]    3
# [13,]    3
# [14,]    1
# [15,]    3
# [16,]    2
# [17,]    2
# [18,]    1
# [19,]    3
# [20,]    3
# [21,]    2
# [22,]    2
# [23,]    2
# [24,]    1
# [25,]    3
# [26,]    3
# [27,]    1
# [28,]    2
# [29,]    2
# [30,]    1
# [31,]    3
# [32,]    3
# [33,]    3
# [34,]    3
# [35,]    1
# [36,]    1
# [37,]    1
# [38,]    3
# [39,]    2
# [40,]    1
# [41,]    2
# [42,]    2
# [43,]    3
# [44,]    1
# [45,]    2
# [1] "FRBCS.W: percentage Error on Iris"
# [1] 4.444444

# %%
## Display the FRBS model
summary(object)
# Out:
# The name of model:  sim-0
# Model was trained using:  FRBCS.W
# The names of attributes:  Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# The interval of input data:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width
# min          4.3         2.0          1.0         0.1
# max          7.9         4.4          6.9         2.5
# Type of FRBS model:
# [1] "FRBCS"
# Type of membership functions:
# [1] "GAUSSIAN"
# Type of t-norm method:
# [1] "Standard t-norm (min)"
# Type of s-norm method:
# [1] "Standard s-norm"
# Type of implication function:
# [1] "ZADEH"
# The names of linguistic terms on the input variables:
#  [1] "vv.small" "v.small"  "small"    "medium"   "large"    "v.large"
#  [7] "vv.large" "vv.small" "v.small"  "small"    "medium"   "large"
# [13] "v.large"  "vv.large" "vv.small" "v.small"  "small"    "medium"
# [19] "large"    "v.large"  "vv.large" "vv.small" "v.small"  "small"
# [25] "medium"   "large"    "v.large"  "vv.large"
# The parameter values of membership function on the input variable (normalized):
#        vv.small    v.small      small     medium      large    v.large
# [1,] 5.00000000 5.00000000 5.00000000 5.00000000 5.00000000 5.00000000
# [2,] 0.00000000 0.16666667 0.33333333 0.50000000 0.66666667 0.83333333
# [3,] 0.05833333 0.05833333 0.05833333 0.05833333 0.05833333 0.05833333
# [4,]         NA         NA         NA         NA         NA         NA
# [5,]         NA         NA         NA         NA         NA         NA
#        vv.large   vv.small    v.small      small     medium      large
# [1,] 5.00000000 5.00000000 5.00000000 5.00000000 5.00000000 5.00000000
# [2,] 1.00000000 0.00000000 0.16666667 0.33333333 0.50000000 0.66666667
# [3,] 0.05833333 0.05833333 0.05833333 0.05833333 0.05833333 0.05833333
# [4,]         NA         NA         NA         NA         NA         NA
# [5,]         NA         NA         NA         NA         NA         NA
#         v.large   vv.large   vv.small    v.small      small     medium
# [1,] 5.00000000 5.00000000 5.00000000 5.00000000 5.00000000 5.00000000
# [2,] 0.83333333 1.00000000 0.00000000 0.16666667 0.33333333 0.50000000
# [3,] 0.05833333 0.05833333 0.05833333 0.05833333 0.05833333 0.05833333
# [4,]         NA         NA         NA         NA         NA         NA
# [5,]         NA         NA         NA         NA         NA         NA
#           large    v.large   vv.large   vv.small    v.small      small
# [1,] 5.00000000 5.00000000 5.00000000 5.00000000 5.00000000 5.00000000
# [2,] 0.66666667 0.83333333 1.00000000 0.00000000 0.16666667 0.33333333
# [3,] 0.05833333 0.05833333 0.05833333 0.05833333 0.05833333 0.05833333
# [4,]         NA         NA         NA         NA         NA         NA
# [5,]         NA         NA         NA         NA         NA         NA
#          medium      large    v.large   vv.large
# [1,] 5.00000000 5.00000000 5.00000000 5.00000000
# [2,] 0.50000000 0.66666667 0.83333333 1.00000000
# [3,] 0.05833333 0.05833333 0.05833333 0.05833333
# [4,]         NA         NA         NA         NA
# [5,]         NA         NA         NA         NA
# The number of linguistic terms on each variables
#      Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# [1,]            7           7            7           7       3
# The fuzzy IF-THEN rules:
#    V1           V2 V3       V4  V5          V6 V7       V8  V9          V10 V11
# 1  IF Sepal.Length is   medium and Sepal.Width is    small and Petal.Length  is
# 2  IF Sepal.Length is  v.large and Sepal.Width is    large and Petal.Length  is
# 3  IF Sepal.Length is    large and Sepal.Width is   medium and Petal.Length  is
# 4  IF Sepal.Length is    large and Sepal.Width is    small and Petal.Length  is
# 5  IF Sepal.Length is    small and Sepal.Width is    small and Petal.Length  is
# 6  IF Sepal.Length is   medium and Sepal.Width is    small and Petal.Length  is
# 7  IF Sepal.Length is   medium and Sepal.Width is    small and Petal.Length  is
# 8  IF Sepal.Length is  v.small and Sepal.Width is   medium and Petal.Length  is
# 9  IF Sepal.Length is  v.large and Sepal.Width is   medium and Petal.Length  is
# 10 IF Sepal.Length is    large and Sepal.Width is  v.small and Petal.Length  is
# 11 IF Sepal.Length is    small and Sepal.Width is  v.small and Petal.Length  is
# 12 IF Sepal.Length is    small and Sepal.Width is  v.small and Petal.Length  is
# 13 IF Sepal.Length is    small and Sepal.Width is    small and Petal.Length  is
# 14 IF Sepal.Length is    small and Sepal.Width is  v.large and Petal.Length  is
# 15 IF Sepal.Length is    small and Sepal.Width is  v.large and Petal.Length  is
# 16 IF Sepal.Length is    small and Sepal.Width is    large and Petal.Length  is
# 17 IF Sepal.Length is vv.small and Sepal.Width is   medium and Petal.Length  is
# 18 IF Sepal.Length is    large and Sepal.Width is   medium and Petal.Length  is
# 19 IF Sepal.Length is   medium and Sepal.Width is   medium and Petal.Length  is
# 20 IF Sepal.Length is   medium and Sepal.Width is    small and Petal.Length  is
# 21 IF Sepal.Length is   medium and Sepal.Width is   medium and Petal.Length  is
# 22 IF Sepal.Length is  v.small and Sepal.Width is   medium and Petal.Length  is
# 23 IF Sepal.Length is   medium and Sepal.Width is    small and Petal.Length  is
# 24 IF Sepal.Length is vv.large and Sepal.Width is    small and Petal.Length  is
# 25 IF Sepal.Length is    small and Sepal.Width is  v.small and Petal.Length  is
# 26 IF Sepal.Length is  v.small and Sepal.Width is  v.small and Petal.Length  is
# 27 IF Sepal.Length is  v.small and Sepal.Width is    large and Petal.Length  is
# 28 IF Sepal.Length is  v.small and Sepal.Width is    large and Petal.Length  is
# 29 IF Sepal.Length is vv.small and Sepal.Width is    small and Petal.Length  is
# 30 IF Sepal.Length is    small and Sepal.Width is    small and Petal.Length  is
# 31 IF Sepal.Length is vv.large and Sepal.Width is    small and Petal.Length  is
# 32 IF Sepal.Length is    large and Sepal.Width is    small and Petal.Length  is
# 33 IF Sepal.Length is  v.large and Sepal.Width is    small and Petal.Length  is
# 34 IF Sepal.Length is    small and Sepal.Width is    small and Petal.Length  is
# 35 IF Sepal.Length is    large and Sepal.Width is    small and Petal.Length  is
# 36 IF Sepal.Length is   medium and Sepal.Width is  v.small and Petal.Length  is
# 37 IF Sepal.Length is    large and Sepal.Width is    small and Petal.Length  is
# 38 IF Sepal.Length is    small and Sepal.Width is  v.large and Petal.Length  is
# 39 IF Sepal.Length is    large and Sepal.Width is    small and Petal.Length  is
# 40 IF Sepal.Length is  v.large and Sepal.Width is    small and Petal.Length  is
# 41 IF Sepal.Length is    small and Sepal.Width is    small and Petal.Length  is
# 42 IF Sepal.Length is   medium and Sepal.Width is   medium and Petal.Length  is
# 43 IF Sepal.Length is  v.small and Sepal.Width is    small and Petal.Length  is
# 44 IF Sepal.Length is    large and Sepal.Width is   medium and Petal.Length  is
# 45 IF Sepal.Length is  v.small and Sepal.Width is   medium and Petal.Length  is
# 46 IF Sepal.Length is    small and Sepal.Width is   medium and Petal.Length  is
# 47 IF Sepal.Length is    large and Sepal.Width is   medium and Petal.Length  is
# 48 IF Sepal.Length is  v.small and Sepal.Width is    large and Petal.Length  is
# 49 IF Sepal.Length is    small and Sepal.Width is    large and Petal.Length  is
# 50 IF Sepal.Length is   medium and Sepal.Width is    small and Petal.Length  is
# 51 IF Sepal.Length is    large and Sepal.Width is   medium and Petal.Length  is
# 52 IF Sepal.Length is    small and Sepal.Width is  v.large and Petal.Length  is
# 53 IF Sepal.Length is  v.small and Sepal.Width is vv.small and Petal.Length  is
# 54 IF Sepal.Length is vv.large and Sepal.Width is    large and Petal.Length  is
# 55 IF Sepal.Length is    large and Sepal.Width is   medium and Petal.Length  is
# 56 IF Sepal.Length is   medium and Sepal.Width is  v.small and Petal.Length  is
# 57 IF Sepal.Length is   medium and Sepal.Width is    small and Petal.Length  is
# 58 IF Sepal.Length is vv.small and Sepal.Width is    large and Petal.Length  is
# 59 IF Sepal.Length is vv.small and Sepal.Width is   medium and Petal.Length  is
# 60 IF Sepal.Length is    small and Sepal.Width is   medium and Petal.Length  is
# 61 IF Sepal.Length is    large and Sepal.Width is   medium and Petal.Length  is
#         V12 V13         V14 V15      V16  V17     V18 V19 V20
# 1    medium and Petal.Width  is   medium THEN Species  is   2
# 2   v.large and Petal.Width  is vv.large THEN Species  is   3
# 3   v.large and Petal.Width  is  v.large THEN Species  is   3
# 4     large and Petal.Width  is   medium THEN Species  is   2
# 5     large and Petal.Width  is  v.large THEN Species  is   3
# 6     large and Petal.Width  is   medium THEN Species  is   2
# 7     large and Petal.Width  is    large THEN Species  is   2
# 8  vv.small and Petal.Width  is vv.small THEN Species  is   1
# 9   v.large and Petal.Width  is    large THEN Species  is   3
# 10  v.large and Petal.Width  is    large THEN Species  is   3
# 11   medium and Petal.Width  is   medium THEN Species  is   2
# 12   medium and Petal.Width  is    small THEN Species  is   2
# 13   medium and Petal.Width  is   medium THEN Species  is   2
# 14  v.small and Petal.Width  is  v.small THEN Species  is   1
# 15 vv.small and Petal.Width  is  v.small THEN Species  is   1
# 16 vv.small and Petal.Width  is vv.small THEN Species  is   1
# 17 vv.small and Petal.Width  is vv.small THEN Species  is   1
# 18  v.large and Petal.Width  is vv.large THEN Species  is   3
# 19    large and Petal.Width  is    large THEN Species  is   2
# 20    large and Petal.Width  is    large THEN Species  is   3
# 21  v.large and Petal.Width  is vv.large THEN Species  is   3
# 22  v.small and Petal.Width  is  v.small THEN Species  is   1
# 23  v.large and Petal.Width  is    large THEN Species  is   3
# 24 vv.large and Petal.Width  is  v.large THEN Species  is   3
# 25    large and Petal.Width  is  v.large THEN Species  is   3
# 26    small and Petal.Width  is    small THEN Species  is   2
# 27  v.small and Petal.Width  is  v.small THEN Species  is   1
# 28 vv.small and Petal.Width  is vv.small THEN Species  is   1
# 29 vv.small and Petal.Width  is vv.small THEN Species  is   1
# 30    large and Petal.Width  is    large THEN Species  is   2
# 31  v.large and Petal.Width  is  v.large THEN Species  is   3
# 32   medium and Petal.Width  is   medium THEN Species  is   2
# 33  v.large and Petal.Width  is  v.large THEN Species  is   3
# 34    large and Petal.Width  is vv.large THEN Species  is   3
# 35    large and Petal.Width  is    large THEN Species  is   2
# 36   medium and Petal.Width  is    small THEN Species  is   2
# 37    large and Petal.Width  is  v.large THEN Species  is   3
# 38  v.small and Petal.Width  is vv.small THEN Species  is   1
# 39  v.large and Petal.Width  is  v.large THEN Species  is   3
# 40  v.large and Petal.Width  is    large THEN Species  is   3
# 41   medium and Petal.Width  is    small THEN Species  is   2
# 42    large and Petal.Width  is  v.large THEN Species  is   3
# 43 vv.small and Petal.Width  is vv.small THEN Species  is   1
# 44    large and Petal.Width  is    large THEN Species  is   2
# 45  v.small and Petal.Width  is vv.small THEN Species  is   1
# 46  v.small and Petal.Width  is vv.small THEN Species  is   1
# 47  v.large and Petal.Width  is    large THEN Species  is   3
# 48  v.small and Petal.Width  is vv.small THEN Species  is   1
# 49  v.small and Petal.Width  is vv.small THEN Species  is   1
# 50  v.large and Petal.Width  is   medium THEN Species  is   3
# 51    large and Petal.Width  is   medium THEN Species  is   2
# 52 vv.small and Petal.Width  is vv.small THEN Species  is   1
# 53   medium and Petal.Width  is    small THEN Species  is   2
# 54  v.large and Petal.Width  is  v.large THEN Species  is   3
# 55    large and Petal.Width  is  v.large THEN Species  is   3
# 56    large and Petal.Width  is  v.large THEN Species  is   3
# 57   medium and Petal.Width  is    large THEN Species  is   2
# 58 vv.small and Petal.Width  is vv.small THEN Species  is   1
# 59  v.small and Petal.Width  is vv.small THEN Species  is   1
# 60 vv.small and Petal.Width  is vv.small THEN Species  is   1
# 61   medium and Petal.Width  is   medium THEN Species  is   2
# The certainty factor:
#
#  [1,] 0.4965982
#  [2,] 0.5669182
#  [3,] 0.5669182
#  [4,] 0.4965982
#  [5,] 0.5669182
#  [6,] 0.4965982
#  [7,] 0.4965982
#  [8,] 0.4364836
#  [9,] 0.5669182
# [10,] 0.5669182
# [11,] 0.4965982
# [12,] 0.4965982
# [13,] 0.4965982
# [14,] 0.4364836
# [15,] 0.4364836
# [16,] 0.4364836
# [17,] 0.4364836
# [18,] 0.5669182
# [19,] 0.4965982
# [20,] 0.5669182
# [21,] 0.5669182
# [22,] 0.4364836
# [23,] 0.5669182
# [24,] 0.5669182
# [25,] 0.5669182
# [26,] 0.4965982
# [27,] 0.4364836
# [28,] 0.4364836
# [29,] 0.4364836
# [30,] 0.4965982
# [31,] 0.5669182
# [32,] 0.4965982
# [33,] 0.5669182
# [34,] 0.5669182
# [35,] 0.4965982
# [36,] 0.4965982
# [37,] 0.5669182
# [38,] 0.4364836
# [39,] 0.5669182
# [40,] 0.5669182
# [41,] 0.4965982
# [42,] 0.5669182
# [43,] 0.4364836
# [44,] 0.4965982
# [45,] 0.4364836
# [46,] 0.4364836
# [47,] 0.5669182
# [48,] 0.4364836
# [49,] 0.4364836
# [50,] 0.5669182
# [51,] 0.4965982
# [52,] 0.4364836
# [53,] 0.4965982
# [54,] 0.5669182
# [55,] 0.5669182
# [56,] 0.5669182
# [57,] 0.4965982
# [58,] 0.4364836
# [59,] 0.4364836
# [60,] 0.4364836
# [61,] 0.4965982

# %% [markdown]
# https://rdrr.io/cran/frbs/src/demo/FRBCS.CHI.Iris.R

# %%
## Input data
data(iris)
set.seed(2)
irisShuffled <- iris[sample(nrow(iris)),]
irisShuffled[,5] <- unclass(irisShuffled[,5])
tra.iris <- irisShuffled[1:105,]
tst.iris <- irisShuffled[106:nrow(irisShuffled),1:4]
real.iris <- matrix(irisShuffled[106:nrow(irisShuffled),5], ncol = 1)
range.data.input <- matrix(c(4.3, 7.9, 2.0, 4.4, 1.0, 6.9, 0.1, 2.5), nrow=2)
 
## Set the method and its parameters
method.type <- "FRBCS.CHI"
control <- list(num.labels = 6, type.mf = "GAUSSIAN", type.tnorm = "MIN", type.snorm = "MAX", type.implication.func = "ZADEH")

## Generate fuzzy model
object <- frbs.learn(tra.iris, range.data.input, method.type, control)

## Predicting step
res.test <- predict(object, tst.iris)

## error calculation
err = 100*sum(real.iris!=res.test)/nrow(real.iris)

print("The result: ")
print(res.test)

print("FRBCS.CHI: percentage Error on Iris")
print(err)
# Out:
# [1] "The result: "
#       [,1]
#  [1,]    2
#  [2,]    2
#  [3,]    1
#  [4,]    2
#  [5,]    1
#  [6,]    1
#  [7,]    3
#  [8,]    1
#  [9,]    2
# [10,]    2
# [11,]    2
# [12,]    3
# [13,]    3
# [14,]    1
# [15,]    3
# [16,]    2
# [17,]    2
# [18,]    1
# [19,]    3
# [20,]    2
# [21,]    2
# [22,]    2
# [23,]    2
# [24,]    1
# [25,]    3
# [26,]    2
# [27,]    1
# [28,]    2
# [29,]    2
# [30,]    1
# [31,]    3
# [32,]    3
# [33,]    3
# [34,]    2
# [35,]    1
# [36,]    1
# [37,]    1
# [38,]    3
# [39,]    2
# [40,]    1
# [41,]    2
# [42,]    2
# [43,]    3
# [44,]    1
# [45,]    2
# [1] "FRBCS.CHI: percentage Error on Iris"
# [1] 11.11111

# %% [markdown]
# https://rdrr.io/cran/frbs/src/demo/GFS.GCCL.Iris.R

# %%
## Input data
data(iris)
set.seed(2)
irisShuffled <- iris[sample(nrow(iris)),]
irisShuffled[,5] <- unclass(irisShuffled[,5])
tra.iris <- irisShuffled[1:105,]
tst.iris <- irisShuffled[106:nrow(irisShuffled),1:4]
real.iris <- matrix(irisShuffled[106:nrow(irisShuffled),5], ncol = 1)
range.data <- matrix(c(4.3, 7.9, 2.0, 4.4, 1.0, 6.9, 0.1, 2.5), nrow=2)

## Set the method and its parameters
method.type <- "GFS.GCCL" 
control <- list(popu.size = 30, num.class = 3, num.labels = 3, persen_cross = 0.9, 
                     max.gen = 200, persen_mutant = 0.3,
                     name="sim-0") 

## Generate fuzzy model
object <- frbs.learn(tra.iris, range.data, method.type, control)

## Predicting step
res.test <- predict(object, tst.iris)

## error calculation
err = 100*sum(real.iris!=res.test)/nrow(real.iris)

print("The result: ")
print(res.test)
print("GFS-GCCL: percentage Error on Iris: ")
print(err)
# Out:
#   |======================================================================| 100%
# [1] "The result: "
#       [,1]
#  [1,]    2
#  [2,]    2
#  [3,]    1
#  [4,]    2
#  [5,]    1
#  [6,]    1
#  [7,]    3
#  [8,]    1
#  [9,]    2
# [10,]    2
# [11,]    2
# [12,]    3
# [13,]    3
# [14,]    1
# [15,]    3
# [16,]    2
# [17,]    2
# [18,]    1
# [19,]    3
# [20,]    2
# [21,]    2
# [22,]    2
# [23,]    2
# [24,]    1
# [25,]    3
# [26,]    2
# [27,]    1
# [28,]    2
# [29,]    2
# [30,]    1
# [31,]    3
# [32,]    2
# [33,]    2
# [34,]    2
# [35,]    1
# [36,]    1
# [37,]    1
# [38,]    3
# [39,]    2
# [40,]    1
# [41,]    2
# [42,]    2
# [43,]    3
# [44,]    1
# [45,]    2
# [1] "GFS-GCCL: percentage Error on Iris: "
# [1] 15.55556

# %% [markdown]
# https://rdrr.io/cran/frbs/src/demo/FH.GBML.Iris.R

# %%
## Input data
data(iris)
set.seed(2)
irisShuffled <- iris[sample(nrow(iris)),]
irisShuffled[,5] <- unclass(irisShuffled[,5])
tra.iris <- irisShuffled[1:105,]
tst.iris <- irisShuffled[106:nrow(irisShuffled),1:4]
real.iris <- matrix(irisShuffled[106:nrow(irisShuffled),5], ncol = 1)
range.data <- matrix(c(4.3, 7.9, 2.0, 4.4, 1.0, 6.9, 0.1, 2.5), nrow=2)

## Set the method and its parameters
method.type <- "FH.GBML" 
control <- list(popu.size = 10, max.num.rule = 50, num.class = 3, 
			persen_cross = 0.9, max.gen = 20, persen_mutant =0.3, p.dcare = 0.5, p.gccl = 0.5, 
			name="sim-0") 
 
## Generate fuzzy model
object <- frbs.learn(tra.iris, range.data, method.type, control)

## Predicting step
res.test <- predict(object, tst.iris)

## error calculation
err = 100*sum(real.iris!=res.test)/nrow(real.iris)

print("The result: ")
print(res.test)
print("FH-GBML: percentage Error on Iris: ")
print(err)
# Out:
#   |======================================================================| 100%
# [1] "The result: "
#       [,1]
#  [1,]    3
#  [2,]    3
#  [3,]    1
#  [4,]    3
#  [5,]    1
#  [6,]    1
#  [7,]    3
#  [8,]    3
#  [9,]    3
# [10,]    2
# [11,]    2
# [12,]    3
# [13,]    3
# [14,]    1
# [15,]    3
# [16,]    2
# [17,]    2
# [18,]    1
# [19,]    3
# [20,]    3
# [21,]    2
# [22,]    2
# [23,]    2
# [24,]    1
# [25,]    3
# [26,]    2
# [27,]    1
# [28,]    2
# [29,]    2
# [30,]    1
# [31,]    3
# [32,]    2
# [33,]    3
# [34,]    2
# [35,]    1
# [36,]    1
# [37,]    1
# [38,]    3
# [39,]    2
# [40,]    1
# [41,]    2
# [42,]    2
# [43,]    3
# [44,]    1
# [45,]    3
# [1] "FH-GBML: percentage Error on Iris: "
# [1] 11.11111

# %% [markdown]
# https://rdrr.io/cran/frbs/src/demo/SLAVE.Iris.R

# %%
## Input data
data(iris)
set.seed(2)
irisShuffled <- iris[sample(nrow(iris)),]
irisShuffled[,5] <- unclass(irisShuffled[,5])
tra.iris <- irisShuffled[1:105,]
tst.iris <- irisShuffled[106:nrow(irisShuffled),1:4]
real.iris <- matrix(irisShuffled[106:nrow(irisShuffled),5], ncol = 1)
range.data <- matrix(c(4.3, 7.9, 2.0, 4.4, 1.0, 6.9, 0.1, 2.5), nrow=2)

## Set the method and its parameters
method.type <- "SLAVE" 
control <- list(num.class = 3, num.labels = 3, persen_cross = 0.9, max.iter = 50, max.gen = 50, 
			        persen_mutant = 0.3, k.lower = 0, k.upper = 1, epsilon = 0.8, name="sim-0") 

## Generate fuzzy model			
object <- frbs.learn(tra.iris, range.data, method.type, control)

## Predicting step
res.test <- predict(object, tst.iris)

## error calculation
err = 100*sum(real.iris!=res.test)/nrow(real.iris)

print("The result: ")
print(res.test)
print("SLAVE: percentage Error on Iris: ")
print(err)
# Out:
#   |======================================================================| 100%
# [1] "The result: "
#       [,1]
#  [1,]    3
#  [2,]    3
#  [3,]    1
#  [4,]    3
#  [5,]    1
#  [6,]    1
#  [7,]    3
#  [8,]    1
#  [9,]    3
# [10,]    2
# [11,]    3
# [12,]    3
# [13,]    3
# [14,]    1
# [15,]    3
# [16,]    2
# [17,]    2
# [18,]    1
# [19,]    3
# [20,]    3
# [21,]    3
# [22,]    3
# [23,]    3
# [24,]    1
# [25,]    3
# [26,]    3
# [27,]    1
# [28,]    3
# [29,]    3
# [30,]    1
# [31,]    3
# [32,]    3
# [33,]    3
# [34,]    3
# [35,]    1
# [36,]    1
# [37,]    1
# [38,]    3
# [39,]    3
# [40,]    1
# [41,]    3
# [42,]    2
# [43,]    3
# [44,]    1
# [45,]    3
# [1] "SLAVE: percentage Error on Iris: "
# [1] 24.44444
